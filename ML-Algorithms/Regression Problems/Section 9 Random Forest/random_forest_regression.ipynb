# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# Random forest is a form of `Ensemble Learning`(Take the same algorithm multiple times to make it more powerful than the original version).
#
# ![Screenshot 2022-07-02 131806.png](data:image/png;base64,...)

# %% [markdown]
# This algorithm decetralized the risk. Instead of taking result from one tree you are averaging on a forest of trees.

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
# !gdown --id 1YOOJLt3nIQ18ofcDFdKSI6VqZZDDb0pJ

dataset = pd.read_csv('random_forest_regression_Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1YOOJLt3nIQ18ofcDFdKSI6VqZZDDb0pJ
# To: /content/random_forest_regression_Position_Salaries.csv
# 100% 246/246 [00:00<00:00, 455kB/s]

# %% [markdown]
# ## Training the Random Forest Regression model on the whole dataset

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 50, random_state = 0)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=0)

# %% [markdown]
# ## Predicting a new result

# %%
regressor.predict([[6.5]])
# Out:
# array([161200.])

# %% [markdown]
# ## Visualising the Random Forest Regression results (higher resolution)

# %%
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (Random Forest Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
